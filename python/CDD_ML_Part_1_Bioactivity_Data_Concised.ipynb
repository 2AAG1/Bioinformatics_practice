# %% [markdown]
# <a href="https://colab.research.google.com/github/2AAG1/Bioinformatics_practice/blob/main/python/CDD_ML_Part_1_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 776.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# ...

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (seventh entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480935                  []
# 1        None             None      1480936                  []
# 2        None             None      1481061                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL830868  In vitro inhibitory concentration against SARS...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                                      target_organism  \
# 0  Severe acute respiratory syndrome-related coro...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# # Copying Files to Google Drive
#
# Firstly, we need to mount the Google Drive into Colab so that we can have acess to our Google drive within Colab

# %%
from google.colab import drive
drive.mount('/content/mydrive/', force_remount=True)
# Out:
# Mounted at /content/mydrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** flder on Google Drive

# %%
! mkdir "/content/mydrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/mydrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data_raw.csv "/content/mydrive/My Drive/Colab Notebooks/data2"

# %%
! ls -l "/content/mydrive/My Drive/Colab Notebooks/data2"
# Out:
# total 156
# -rw------- 1 root root  20135 Jun  4 14:20 bioactivity_data_preprocessed.csv
# -rw------- 1 root root 138803 Jun  5 04:13 bioactivity_data_raw.csv

# %%
! ls
# Out:
# bioactivity_data_raw.csv  mydrive  sample_data

# %%
! head bioactivity_data_raw.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 242  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 245  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 246  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
   bioactivity_class.append("intermediate")

# %% [markdown]
# ### Iterate the molecule_chembl_id to a list

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 242    CHEMBL4590273
# 243    CHEMBL5436771
# 244    CHEMBL2365410
# 245    CHEMBL5436771
# 246    CHEMBL2365410
# Name: molecule_chembl_id, Length: 245, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL187579',
#  'CHEMBL188487',
#  'CHEMBL185698',
#  'CHEMBL426082',
#  'CHEMBL187717',
#  'CHEMBL365134',
#  'CHEMBL187598',
#  'CHEMBL190743',
#  'CHEMBL365469',
#  'CHEMBL188983',
#  'CHEMBL191575',
#  'CHEMBL370923',
#  'CHEMBL194398',
#  'CHEMBL196635',
#  'CHEMBL209287',
#  'CHEMBL358279',
#  'CHEMBL348660',
#  'CHEMBL379727',
#  'CHEMBL210525',
#  'CHEMBL148483',
#  'CHEMBL383725',
#  'CHEMBL118596',
#  'CHEMBL208732',
#  'CHEMBL208732',
#  'CHEMBL210146',
#  'CHEMBL210146',
#  'CHEMBL207458',
#  'CHEMBL207458',
#  'CHEMBL207484',
#  'CHEMBL207484',
#  'CHEMBL207207',
#  'CHEMBL207207',
#  'CHEMBL210487',
#  'CHEMBL210487',
#  'CHEMBL380470',
#  'CHEMBL380470',
#  'CHEMBL210612',
#  'CHEMBL210612',
#  'CHEMBL209667',
#  'CHEMBL209667',
#  'CHEMBL210097',
#  'CHEMBL210097',
#  'CHEMBL378674',
#  'CHEMBL378674',
#  'CHEMBL210216',
#  'CHEMBL210216',
#  'CHEMBL210195',
#  'CHEMBL210195',
#  'CHEMBL210437',
#  'CHEMBL210437',
#  'CHEMBL378677',
#  'CHEMBL378677',
# ...

# %% [markdown]
# ### Iterate canonical_smiles to a list

# %%
df2.canonical_smiles
# Out:
# 0                 Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1                 O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2                O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3                    O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4        O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
#                              ...
# 242                    Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 243                             S=C([S-])NCc1cccnc1.[K+]
# 244    CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245                             S=C([S-])NCc1cccnc1.[K+]
# 246    CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# Name: canonical_smiles, Length: 245, dtype: object

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
canonical_smiles
# Out:
# ['Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21',
#  'O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21',
#  'O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21',
#  'O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21',
#  'O=C1C(=O)N(C/C=C/c2cc3ccccc3s2)c2ccc(I)cc21',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(CN2C(=O)C(=O)c3cc(I)ccc32)s1',
#  'O=C1C(=O)N(Cc2ccc(C(=O)N3CCCCC3)s2)c2ccc(I)cc21',
#  'CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@@H](CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C)Cc1ccccc1',
#  'CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC=C(C)C)CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C',
#  'CCCCN1C(=O)C(=O)c2cc(I)ccc21',
#  'NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccc2ccccc2c1',
#  'NC(=O)c1ccc2c(c1)C(=O)C(=O)N2Cc1ccccc1',
#  'CCCCN1C(=O)C(=O)c2cc(C(N)=O)ccc21',
#  'CCCN1C(=O)C(=O)c2cc(C(N)=O)ccc21',
# ...

# %% [markdown]
# ### Iterate standard_value to a list

# %%
df2.standard_value
# Out:
# 0       7200.0
# 1       9400.0
# 2      13500.0
# 3      13110.0
# 4       2000.0
#         ...
# 242     380.19
# 243      165.0
# 244      161.0
# 245     165.96
# 246     162.18
# Name: standard_value, Length: 245, dtype: object

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
standard_value
# Out:
# ['7200.0',
#  '9400.0',
#  '13500.0',
#  '13110.0',
#  '2000.0',
#  '980.0',
#  '4820.0',
#  '950.0',
#  '11200.0',
#  '23500.0',
#  '12570.0',
#  '17500.0',
#  '45000.0',
#  '70000.0',
#  '66000.0',
#  '370.0',
#  '12500.0',
#  '19000.0',
#  '25000.0',
#  '71000.0',
#  '1100.0',
#  '50000.0',
#  '3019.95',
#  '3000.0',
#  '301995.17',
#  '300000.0',
#  '251188.64',
#  '250000.0',
#  '204173.79',
#  '200000.0',
#  '100000.0',
#  '100000.0',
#  '60255.96',
#  '60000.0',
#  '45708.82',
#  '45000.0',
#  '40738.03',
#  '40000.0',
#  '15135.61',
#  '15000.0',
#  '15135.61',
#  '15000.0',
#  '12022.64',
#  '12000.0',
#  '1000000.0',
#  '1000000.0',
#  '501187.23',
#  '500000.0',
#  '407380.28',
#  '400000.0',
#  '354813.39',
#  '350000.0',
#  '301995.17',
#  '300000.0',
#  '301995.17',
#  '300000.0',
#  '204173.79',
#  '200000.0',
#  '204173.79',
#  '200000.0',
#  '204173.79',
#  '200000.0',
#  '204173.79',
#  '200000.0',
#  '60255.96',
#  '60000.0',
#  '40738.03',
#  '40000.0',
# ...

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 242      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %% [markdown]
# ### **Combine the 4 lists into dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 240      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 241      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 242      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     bioactivity_class standard_value
# 0        intermediate         7200.0
# ...

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 240      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 241      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 242      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     bioactivity_class standard_value bioactivity_class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df4.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 168
# -rw-r--r-- 1 root root  23042 Jun  5 04:14 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 138803 Jun  5 04:13 bioactivity_data_raw.csv
# drwx------ 6 root root   4096 Jun  5 04:13 mydrive
# drwxr-xr-x 1 root root   4096 Jun  3 14:04 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_data_preprocessed.csv "/content/mydrive/My Drive/Colab Notebooks/data2"

# %%
! ls "/content/mydrive/My Drive/Colab Notebooks/data2"
# Out:
# bioactivity_data_preprocessed.csv  bioactivity_data_raw.csv

# %% [markdown]
# ---
